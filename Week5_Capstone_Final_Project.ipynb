# %% [markdown]
# # IBM Applied Data Science Capstone Course by Coursera
# ### Week 5 Final Report
# **_Opening a New Spa in Mumbai_**
# - Build a dataframe of neighborhoods in Mumbai  by web scraping the data from Wikipedia page
# - Get the geographical coordinates of the neighborhoods
# - Obtain the venue data for the neighborhoods from Foursquare API
# - Explore and cluster the neighborhoods
# - Select the best cluster to open a new shopping mall
# ***
# ### 1. Import libraries

# %%
#!conda update -n base -c defaults conda --yes
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests

#import BeautifulSoup # library to parse HTML and XML documents
# !conda install -c conda beautifulsoup4 --yes

#import beautifulsoup4
from bs4 import BeautifulSoup # library to parse HTML and XML documents

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library
#!conda install -c conda geocoder --yes
#import geocoder # to get coordinates

print("Libraries imported.")
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#
# The following packages will be UPDATED:
#
#     certifi: 2019.6.16-py36_1  --> 2019.6.16-py36_1  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl: 1.0.2s-h7b6447c_0 --> 1.0.2r-h14c3975_0 conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.6.16          |           py36_1         156 KB
#
# The following packages will be UPDATED:
#
#     certifi: 2019.6.16-py36_1  conda-forge --> 2019.6.16-py36_1
#     openssl: 1.0.2r-h14c3975_0 conda-forge --> 1.0.2s-h7b6447c_0
#
#
# Downloading and Extracting Packages
# certifi-2019.6.16    | 156 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 2. Scrap data from Wikipedia page into a DataFrame

# %%
data = requests.get("https://en.wikipedia.org/wiki/Category:Neighbourhoods_in_Mumbai").text

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(data, 'html.parser')

# %%
# create a list to store neighborhood data
neighborhoodList = []

# %%
# append the data into the list
for row in soup.find_all("div", class_="mw-category")[0].findAll("li"):
    neighborhoodList.append(row.text)

# %%
# create a new DataFrame from the list
kl_df = pd.DataFrame({"Neighborhood": neighborhoodList})
kl_df = kl_df.drop(kl_df.index[0])
kl_df['Neighborhood'] = kl_df['Neighborhood'].str.replace(',', ' ')
kl_df['Neighborhood'] = kl_df['Neighborhood'].str.replace('(', '')
kl_df['Neighborhood'] = kl_df['Neighborhood'].str.replace(')', '')
kl_df['Neighborhood'] = kl_df['Neighborhood'].str.replace('`', '')
kl_df['Neighborhood'] = kl_df['Neighborhood'].str.replace('.', '')
kl_df
# Out:
#                       Neighborhood
# 1                Aarey Milk Colony
# 2                         Agripada
# 3                   Altamount Road
# 4                   Amboli  Mumbai
# 5                      Amrut Nagar
# 6                       Antop Hill
# 7                  Anushakti Nagar
# 8                           Asalfa
# 9                     Badhwar Park
# 10                      Baiganwadi
# 11                  Ballard Estate
# 12                          Bandra
# 13            Bandra Kurla Complex
# 14                    Bangur Nagar
# 15                      Bhuleshwar
# 16                     Bori Bunder
# 17                    Breach Candy
# 18                         Byculla
# 19                      CGS colony
# 20                           Cavel
# 21             Chandanwadi  Mumbai
# 22                      Chandivali
# 23                     Chinchpokli
# 24                    Chira Bazaar
# 25                     Chor Bazaar
# 26                      Churchgate
# 27                          Colaba
# 28                    Cotton Green
# 29                    Cuffe Parade
# 30                    Cumbala Hill
# 31     Currey Road railway station
# 32                        DN Nagar
# 33                           Dadar
# 34              Dadar Parsi Colony
# 35                     Dagdi Chawl
# 36                     Dava Bazaar
# 37                      Dedh galli
# 38                          Deonar
# 39                         Dharavi
# 40                      Dhobitalao
# 41                        Dindoshi
# 42                          Dongri
# 43                      Fanas Wadi
# 44                     Ferry Wharf
# 45            Fort Mumbai precinct
# 46                  Four Bungalows
# 47                       Gavangaon
# 48                       Ghodapdeo
# 49                         Girgaon
# 50                       Gokuldham
# 51                           Gorai
# 52                    Gowalia Tank
# 53         Guru Tegh Bahadur Nagar
# 54                    Hindu colony
# 55     Hiranandani Gardens  Mumbai
# 56                       IC Colony
# 57                            Irla
# 58                   Jagruti Nagar
# 59                        JB Nagar
# 60                        Kajuwadi
# 61                      Kala Ghoda
# 62                       Kalbadevi
# 63                     Kamathipura
# 64                 Kannamwar Nagar
# 65                    Kemps Corner
# 66                      Khar Danda
# 67                        Kherwadi
# 68                    Khotachiwadi
# 69                        Koliwada
# 70                     Koombarwara
# 71                      Kopar Road
# 72                         Lalbaug
# 73              Lallubhai Compound
# 74              Land's End  Bandra
# 75                Lion Gate Mumbai
# 76                     Lohar Chawl
# 77             Lokhandwala Complex
# 78                     Madh Island
# 79               Mahalaxmi  Mumbai
# 80        Maheshwari Udyan  Mumbai
# 81                           Mahim
# 82                           Mahul
# 83                    Malabar Hill
# 84                           Malad
# 85                  Mandvi  Mumbai
# 86                          Manori
# 87            Marine Drive  Mumbai
# 88                    Marine Lines
# 89                           Marol
# 90            Matunga Road  Mumbai
# 91                        Mazagaon
# 92                 Mendham's Point
# 93                       Mira Road
# 94                         Nagpada
# 95                     Nala Sopara
# 96                      Nana Chowk
# 97                   Nariman Point
# 98                      Navy Nagar
# 99                     Charni Road
# 100                Nepean Sea Road
# 101                    Null Bazaar
# 102       Royal Opera House Mumbai
# 103                          Orlem
# 104                       Oshiwara
# 105                      Pali Hill
# 106                   Pali Village
# 107                          Parel
# 108                    Pedder Road
# 109                         Poisar
# 110                          Powai
# 111                     Prabhadevi
# 112         Princess Street Mumbai
# 113                       Pydhonie
# 114                      Saki Naka
# 115                          SEEPZ
# 116                          Sewri
# 117        Shastri Nagar  Goregaon
# 118                       Shimpoli
# 119                   Shivaji Park
# 120  Shivaji Park Residential Zone
# 121                    SPDC Colony
# 122                   Sunder Nagar
# 123                         Tardeo
# 124           Thakkar Bappa Colony
# 125                     Thakurdwar
# 126                      Umarkhadi
# 127                           Uran
# 128                Versova  Mumbai
# 129                     Vidyavihar
# 130                          Virar
# 131                         Wadala
# 132                     Walkeshwar
# 133         Wellington Pier Bombay
# 134         Western Suburbs Mumbai
# 135                      Yashodham
# 136                  Zaveri Bazaar

# %%
# print the number of rows of the dataframe
kl_df.shape
# Out:
# (136, 1)

# %% [markdown]
# ## 3. Get the geographical coordinates

# %%
geolocator = Nominatim(user_agent="specify_your_app_name_here")
d = pd.DataFrame()
for neighborhood in kl_df["Neighborhood"].tolist():
    lat_lng_coords = geolocator.geocode('{}, Mumbai'.format(neighborhood), timeout=None)
    if lat_lng_coords:
        if lat_lng_coords.latitude:
            if lat_lng_coords.longitude:
                #print(neighborhood,lat_lng_coords.latitude,lat_lng_coords.longitude)
                temp = pd.DataFrame({'Neighborhood': [neighborhood], 'Latitude': [lat_lng_coords.latitude], 'Longitude':[lat_lng_coords.longitude]})
                d = pd.concat([d, temp])

kl_df = pd.DataFrame(d)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: `timeout=None` has been passed to a geocoder call. Using default geocoder timeout. In geopy 2.0 the behavior will be different: None will mean "no timeout" instead of "default geocoder timeout". Pass geopy.geocoders.base.DEFAULT_SENTINEL instead of None to get rid of this warning.
#   after removing the cwd from sys.path.

# %%
# save the DataFrame as CSV file
kl_df.to_csv("kl_df.csv", index=False)

# %% [markdown]
# ## 4. Create a map of Mumbai with neighborhoods superimposed on top

# %%
# get the coordinates of Mumbai
address = 'Mumbai'

geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Mumbai {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Mumbai 18.9387711, 72.8353355.

# %%
# create map of Mumbai using latitude and longitude values
map_kl = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, neighborhood in zip(kl_df['Latitude'], kl_df['Longitude'], kl_df['Neighborhood']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_kl)  
    
map_kl
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# save the map as HTML file
map_kl.save('map_kl.html')

# %% [markdown]
# ## 5. Use the Foursquare API to explore the neighborhoods

# %%
# define Foursquare Credentials and Version
#CLIENT_ID = 'UKQKXBNYSA0MCNAHWV2MD4RUUMGOL0DUQJGIE5JOWRIWRLTM' # your Foursquare ID  
#CLIENT_SECRET = 'AA10SDBSCHFCVIU0MOQS0QFL0OZ2123DV3UHQYFQR0U5WAGC' # your Foursquare Secret

#CLIENT_ID = 'NXRIWY0MHBMSOII4A4TQ0QAY2LHN5XNOD1JUCGCW1QNZDUOX' # your Foursquare ID    
#CLIENT_SECRET = 'NHVZK1LYGWN0KZKLEZ20B2RYX2J0XV4GKWHEY0JXEWAROYNN' # your Foursquare Secret


CLIENT_ID = 'XF0NPKISHXD2Z0HQVRRYZAD3Y4P10ZTIT3P0RT15QLCXUMII' # your Foursquare ID    
CLIENT_SECRET = 'HRXFXCZIQSQJWABUFIPGHNSL51BIOPV3JFH1YNGDISMDU1TG' # your Foursquare Secret

VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: XF0NPKISHXD2Z0HQVRRYZAD3Y4P10ZTIT3P0RT15QLCXUMII
# CLIENT_SECRET:HRXFXCZIQSQJWABUFIPGHNSL51BIOPV3JFH1YNGDISMDU1TG

# %%
search_query = 'spa'
radius = 2000
LIMIT = 50
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=XF0NPKISHXD2Z0HQVRRYZAD3Y4P10ZTIT3P0RT15QLCXUMII&client_secret=HRXFXCZIQSQJWABUFIPGHNSL51BIOPV3JFH1YNGDISMDU1TG&ll=18.9387711,72.8353355&v=20180605&query=spa&radius=2000&limit=50'

# %%
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.tail()
# Out:
#                           id  \
# 17  4e53fdf022711d4da5c37e3b
# 18  4df98115e4cd56a649835da6
# 19  4b854372f964a5207a5331e3
# 20  54ddac44498ee59badc17324
# 21  4f2f48d5e4b0bd78b8cad496
#
#                                                 name  \
# 17                                Spacematrix Mumbai
# 18                                      Space Matrix
# 19                                 Spaghetti Kitchen
# 20  DBS Corporate Services - Commercial Office Space
# 21                        Consulate General of Spain
#
#                                            categories    referralId  hasPerk  \
# 17  [{'id': '4bf58dd8d48988d174941735', 'name': 'C...  v-1566240689    False
# 18  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1566240689    False
# 19                                                 []  v-1566240689    False
# 20  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1566240689    False
# 21  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...  v-1566240689    False
#
#                               location.address  \
# 17                                         NaN
# 18                                         NaN
# 19         CR2, 1st Floor, CR2, Inox Building,
# 20  Raheja Chambers, 2nd Floor, Nariman Point,
# 21                          Maker Chambers IV,
#
#                 location.crossStreet  location.lat  location.lng  \
# 17                               NaN     18.933575     72.824279
# 18                               NaN     18.933897     72.825356
# 19  Opp. Bajaj Bhavan, Nariman Point     18.926485     72.822358
# 20                               NaN     18.923878     72.823592
# 21                     Nariman point     18.934619     72.826741
#
#                               location.labeledLatLngs  location.distance  \
# 17  [{'label': 'display', 'lat': 18.933575, 'lng':...               1299
# 18  [{'label': 'display', 'lat': 18.933897, 'lng':...               1182
# 19  [{'label': 'display', 'lat': 18.92648457897770...               1933
# 20  [{'label': 'display', 'lat': 18.92387808125605...               2068
# 21  [{'label': 'display', 'lat': 18.93461945611798...               1016
#
#    location.postalCode location.cc location.city location.state  \
# 17                 NaN          IN        Mumbai    Mahārāshtra
# 18                 NaN          IN        Mumbai    Mahārāshtra
# 19             400 021          IN        Mumbai    Mahārāshtra
# 20              400021          IN        Mumbai    Mahārāshtra
# 21                 NaN          IN        Mumbai    Mahārāshtra
#
#    location.country                          location.formattedAddress
# 17            India                       [Mumbai, Mahārāshtra, India]
# 18            India                       [Mumbai, Mahārāshtra, India]
# 19            India  [CR2, 1st Floor, CR2, Inox Building, (Opp. Baj...
# 20            India  [Raheja Chambers, 2nd Floor, Nariman Point,, M...
# 21            India  [Maker Chambers IV, (Nariman point), Mumbai, M...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
dataframe_filtered = dataframe_filtered.rename(columns = {"location.lat": "lat", 
                                  "location.lng":"lng"})

dataframe_filtered['name'] = dataframe_filtered['name'].str.replace(',', ' ')
dataframe_filtered['name'] = dataframe_filtered['name'].str.replace('(', '')
dataframe_filtered['name'] = dataframe_filtered['name'].str.replace(')', '')
dataframe_filtered['name'] = dataframe_filtered['name'].str.replace('`', '')
dataframe_filtered['name'] = dataframe_filtered['name'].str.replace('.', '')
dataframe_filtered['name'] = dataframe_filtered['name'].str.replace('-', '')

dataframe_filtered
# Out:
#                                                name  \
# 0                                          Jiva Spa
# 1                                Monalisa salon spa
# 2                                         Mudra Spa
# 3                                     The Palms Spa
# 4                                         Myrah spa
# 5                                 Oro Salon And Spa
# 6                                        Oberoi Spa
# 7                   Sukho Thai Spa  COLABA CAUSEWAY
# 8                             Muktaa The Luxury Spa
# 9             Suko Thai Spa  Hotel Taj Mahel Mumbai
# 10                                      Moksham Spa
# 11                 There She Glows Salon & Nail Spa
# 12                                          Trident
# 13                                         Aura Spa
# 14                                   The Health Spa
# 15                           Sparkwater Productions
# 16                                 Method Art Space
# 17                               Spacematrix Mumbai
# 18                                     Space Matrix
# 19                                Spaghetti Kitchen
# 20  DBS Corporate Services  Commercial Office Space
# 21                       Consulate General of Spain
#
#                                            categories  \
# 0   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 1   [{'id': '4bf58dd8d48988d110951735', 'name': 'S...
# 2   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 3   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 4   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 5   [{'id': '4bf58dd8d48988d110951735', 'name': 'S...
# 6   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 7   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 8   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 9   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 10  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 11  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 12  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...
# 13                                                 []
# 14  [{'id': '4bf58dd8d48988d131941735', 'name': 'S...
# 15  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...
# 16  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...
# 17  [{'id': '4bf58dd8d48988d174941735', 'name': 'C...
# 18  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...
# 19                                                 []
# 20  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...
# 21  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...
#
#                                      location.address  \
# 0                              P. J. Ramchandani Marg
# 1   Shop No.2,2&4,Fantasy Apts.J.P. Road, 7Bungalo...
# 2                                                 NaN
# 3                                       Dhanraj Mahal
# 4                                                 NaN
# 5                                             Jabreya
# 6                                                 NaN
# 7   Crescent House, 1st Floor, Near McDonalds, Col...
# 8                                Babubhai Chinai Road
# 9                                              Mumbai
# 10                                    Colaba Causeway
# 11                                                NaN
# 12                                      Nariman Point
# 13                                             Colaba
# 14                                                NaN
# 15                                         Hornbyview
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                CR2, 1st Floor, CR2, Inox Building,
# 20         Raheja Chambers, 2nd Floor, Nariman Point,
# 21                                 Maker Chambers IV,
#
#                 location.crossStreet        lat        lng  \
# 0                      Apollo Bunder  18.921927  72.832845
# 1                                NaN  18.931828  72.830999
# 2                                NaN  18.930599  72.823088
# 3                                NaN  18.924603  72.833486
# 4                                NaN  18.944767  72.824715
# 5                                NaN  18.943823  72.823677
# 6                                NaN  18.927245  72.820647
# 7                                NaN  18.923409  72.831877
# 8                          1st floor  18.930225  72.823160
# 9                                NaN  18.922113  72.832765
# 10                               NaN  18.923156  72.831778
# 11                               NaN  18.922269  72.830670
# 12                               NaN  18.927878  72.820711
# 13                               NaN  18.919827  72.830099
# 14                               NaN  18.952947  72.819984
# 15                               NaN  18.934840  72.834302
# 16                               NaN  18.929577  72.832085
# 17                               NaN  18.933575  72.824279
# 18                               NaN  18.933897  72.825356
# 19  Opp. Bajaj Bhavan, Nariman Point  18.926485  72.822358
# 20                               NaN  18.923878  72.823592
# 21                     Nariman point  18.934619  72.826741
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 18.92192744189440...               1893
# 1   [{'label': 'display', 'lat': 18.93182798364119...                897
# 2   [{'label': 'display', 'lat': 18.93059939634803...               1578
# 3   [{'label': 'display', 'lat': 18.92460257892114...               1589
# 4   [{'label': 'display', 'lat': 18.944767, 'lng':...               1302
# 5   [{'label': 'display', 'lat': 18.94382286071777...               1350
# 6   [{'label': 'display', 'lat': 18.92724547743426...               2009
# 7   [{'label': 'display', 'lat': 18.92340869186683...               1748
# 8   [{'label': 'display', 'lat': 18.930225, 'lng':...               1596
# 9   [{'label': 'display', 'lat': 18.92211256518864...               1874
# 10  [{'label': 'display', 'lat': 18.92315606529770...               1778
# 11  [{'label': 'display', 'lat': 18.922269, 'lng':...               1901
# 12  [{'label': 'display', 'lat': 18.92787752948028...               1960
# 13  [{'label': 'display', 'lat': 18.91982661864659...               2179
# 14  [{'label': 'display', 'lat': 18.95294713578247...               2258
# 15  [{'label': 'display', 'lat': 18.93484, 'lng': ...                450
# 16  [{'label': 'display', 'lat': 18.929577, 'lng':...               1079
# 17  [{'label': 'display', 'lat': 18.933575, 'lng':...               1299
# 18  [{'label': 'display', 'lat': 18.933897, 'lng':...               1182
# 19  [{'label': 'display', 'lat': 18.92648457897770...               1933
# 20  [{'label': 'display', 'lat': 18.92387808125605...               2068
# 21  [{'label': 'display', 'lat': 18.93461945611798...               1016
#
#    location.postalCode location.cc  location.city location.state  \
# 0              400 001          IN         Mumbai    Mahārāshtra
# 1                  NaN          IN  MUMBAI-400061            NaN
# 2                  NaN          IN            NaN            NaN
# 3               400039          IN         Mumbai    Mahārāshtra
# 4                  NaN          IN            NaN            NaN
# 5                  NaN          IN            NaN            NaN
# 6                  NaN          IN            NaN            NaN
# 7               400039          IN         Mumbai    Mahārāshtra
# 8               400020          IN         Mumbai    Mahārāshtra
# 9                  NaN          IN            NaN            NaN
# 10                 NaN          IN            NaN            NaN
# 11              400005          IN         Mumbai    Mahārāshtra
# 12             400 021          IN         Mumbai    Mahārāshtra
# 13                 NaN          IN         Mumbai    Mahārāshtra
# 14                 NaN          IN            NaN            NaN
# 15                 NaN          IN            NaN            NaN
# 16              400001          IN         Mumbai    Mahārāshtra
# 17                 NaN          IN         Mumbai    Mahārāshtra
# 18                 NaN          IN         Mumbai    Mahārāshtra
# 19             400 021          IN         Mumbai    Mahārāshtra
# 20              400021          IN         Mumbai    Mahārāshtra
# 21                 NaN          IN         Mumbai    Mahārāshtra
#
#    location.country                          location.formattedAddress  \
# 0             India  [P. J. Ramchandani Marg (Apollo Bunder), Mumba...
# 1             India  [Shop No.2,2&4,Fantasy Apts.J.P. Road, 7Bungal...
# 2             India                                            [India]
# 3             India  [Dhanraj Mahal, Mumbai 400039, Mahārāshtra, In...
# 4             India                                            [India]
# 5             India                                   [Jabreya, India]
# 6             India                                            [India]
# 7             India  [Crescent House, 1st Floor, Near McDonalds, Co...
# 8             India  [Babubhai Chinai Road (1st floor), Mumbai 4000...
# 9             India                                    [Mumbai, India]
# 10            India                           [Colaba Causeway, India]
# 11            India                [Mumbai 400005, Mahārāshtra, India]
# 12            India  [Nariman Point, Mumbai 400 021, Mahārāshtra, I...
# 13            India               [Colaba, Mumbai, Mahārāshtra, India]
# 14            India                                            [India]
# 15            India                                [Hornbyview, India]
# 16            India                [Mumbai 400001, Mahārāshtra, India]
# 17            India                       [Mumbai, Mahārāshtra, India]
# 18            India                       [Mumbai, Mahārāshtra, India]
# 19            India  [CR2, 1st Floor, CR2, Inox Building, (Opp. Baj...
# 20            India  [Raheja Chambers, 2nd Floor, Nariman Point,, M...
# 21            India  [Maker Chambers IV, (Nariman point), Mumbai, M...
#
#                           id
# 0   4b0587e7f964a52074a622e3
# 1   50a12db7e4b0c6336f56cdd6
# 2   51a6122a498eb8bf3e6b993a
# 3   4f433c99e4b0c5334e561cc1
# 4   56fa1abd498eafeb77ff18c8
# 5   54cf5f1d498e775a90c90be1
# 6   50e17384e4b08361cd792a37
# 7   5be6be80772fbc002c8a6eea
# 8   5a9d20258c35dc30f43939cd
# 9   4feb23c7e4b076a38bc7b986
# 10  544cebca498e767f777a4f63
# 11  5b251d57b3c961002c025349
# 12  4c1efc7963750f474693ba67
# 13  4df4c7bf22718759f8243750
# 14  56deff87cd10cc066f27ada7
# 15  51221476e4b0d82e6b15cd41
# 16  5d4b024a735c2d0007253828
# 17  4e53fdf022711d4da5c37e3b
# 18  4df98115e4cd56a649835da6
# 19  4b854372f964a5207a5331e3
# 20  54ddac44498ee59badc17324
# 21  4f2f48d5e4b0bd78b8cad496

# %%
# add the spa as red circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(map_kl)

# display map
map_kl
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
